# %% [markdown]
# <h1 style="color:red; text-align:center;">Titanic Survive Prediction (Random Forest Model)</h1>

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\bmsha\Downloads\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h1 style="color:red;">Data Cleaning</h1>

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df[['Cabin','Embarked']]=df[['Cabin','Embarked']].fillna(method='bfill')

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
df['Sex']=df['Sex'].map({'female':0,'male':1})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [raw]
# x=df[['Pclass','Sex','Age','SibSp','Parch','Fare']]
# y=df['Survived']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# <h1 style="color:red;"> Model building</h1>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
ypred=rf.predict(xtest)
# print(ypred)

# %% [markdown]
# <h1 style="color:red;">Accuracy</h1>

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(ytest,ypred)
print('Acuuracy=',acc)
# Out:
# Acuuracy= 0.7988826815642458

# %%
from sklearn.metrics import classification_report

# %%
clsrep=classification_report(ytest,ypred)
print("Classicification Report",clsrep)
# Out:
# Classicification Report               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       105
#            1       0.77      0.73      0.75        74
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
# rf.score(xtrain,ytrain)
# Out:
# 0.9789325842696629

# %%
sample=xtest.iloc[0:1]

# %%
sample
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 709       3    1  28.0      1      1  15.2458

# %%
print(rf.predict(sample))
# Out:
# [0]

# %%
samp=xtest.iloc[0:10]
pred=rf.predict(samp)

# %%
samp
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 709       3    1  28.0      1      1  15.2458
# 439       2    1  31.0      0      0  10.5000
# 840       3    1  20.0      0      0   7.9250
# 720       2    0   6.0      0      1  33.0000
# 39        3    0  14.0      1      0  11.2417
# 290       1    0  26.0      0      0  78.8500
# 300       3    0  28.0      0      0   7.7500
# 333       3    1  16.0      2      0  18.0000
# 208       3    0  16.0      0      0   7.7500
# 136       1    0  19.0      0      2  26.2833

# %%
pred
# Out:
# array([0, 0, 0, 1, 0, 1, 1, 0, 1, 1], dtype=int64)
